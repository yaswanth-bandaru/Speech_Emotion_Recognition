# %%
import pandas as pd
import numpy as np
import os
import sys
import glob 
import matplotlib.pyplot as plt
import random
import seaborn as sns
import librosa
import librosa.display
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.utils.multiclass import unique_labels
from sklearn.neural_network import MLPClassifier
import xgboost as xgb
import optuna
from tqdm import tqdm
import lightgbm as lgb

import keras
import tensorflow as tf
from keras import layers
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras import optimizers
from keras.regularizers import l2
import warnings
warnings.filterwarnings('ignore')

# %%
emotions={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}

def gender(g):
    """Returns Gender Label"""
    if int(g[0:2]) % 2 == 0:
        return 'female'
    else:
        return 'male'

# %%
def extract_feature(file_name):
    """Function Extracts Features from WAV file"""
    X, sample_rate = librosa.load(file_name)
    stft=np.abs(librosa.stft(X))
    result=np.array([])
    mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
    result=np.hstack((result, mfccs))
    chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
    result=np.hstack((result, chroma))
    mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
    result=np.hstack((result, mel))
    return result

# %%
def load_data(test_size=0.2):
    """Loads Data from directory containing WAV files."""
    x,y=[],[]
    for file in tqdm(glob.glob("Y:/Masters_Content/Deep_Learning/Project/Data/Data/Actor_*/*.wav")):
        file_name=os.path.basename(file)
        emotion=emotions[file_name.split("-")[2]] + '_' + gender(file_name.split("-")[-1])
        feature=extract_feature(file)
        x.append(feature)
        y.append(emotion)
    return train_test_split(np.array(x), y, test_size=test_size, random_state=9)

# %%
X_train, X_test, y_train, y_test = load_data()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1440/1440 [03:19<00:00,  7.23it/s]

# %%
X_train = np.asarray(X_train)
y_train= np.asarray(y_train)
X_test=np.array(X_test)
y_test=np.array(y_test)

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((1152, 180), (1152,), (288, 180), (288,))

# %%
x_traincnn = X_train[:,:,np.newaxis]
x_testcnn = X_test[:,:,np.newaxis]

# %%
x_traincnn.shape,x_testcnn.shape
# Out:
# ((1152, 180, 1), (288, 180, 1))

# %%
lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)

# %%
targets = lb.classes_
targets
# Out:
# array(['angry_female', 'angry_male', 'calm_female', 'calm_male',
#        'disgust_female', 'disgust_male', 'fearful_female', 'fearful_male',
#        'happy_female', 'happy_male', 'neutral_female', 'neutral_male',
#        'sad_female', 'sad_male', 'surprised_female', 'surprised_male'],
#       dtype='<U16')

# %%
lb = LabelEncoder()
y_train_1 = to_categorical(lb.fit_transform(y_train))
y_test_1 = to_categorical(lb.fit_transform(y_test))

# %%
model = tf.keras.Sequential()
model.add(layers.Conv1D(64, kernel_size=(10), activation='relu', input_shape=(X_train.shape[1],1)))
model.add(layers.Conv1D(128, kernel_size=(10),activation='relu',kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
model.add(layers.MaxPooling1D(pool_size=(8)))
model.add(layers.Dropout(0.4))
model.add(layers.Conv1D(128, kernel_size=(10),activation='relu'))
model.add(layers.MaxPooling1D(pool_size=(8)))
model.add(layers.Dropout(0.4))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(16, activation='sigmoid'))
opt = keras.optimizers.Adam(lr=0.001)
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 171, 64)           704
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 162, 128)          82048
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 20, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 11, 128)           163968
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 1, 128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 128)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               33024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                4112
# =================================================================
# Total params: 283,856
# Trainable params: 283,856
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint("best_initial_model.hdf5", monitor='val_accuracy', verbose=1,
    save_best_only=True, mode='max', period=1, save_weights_only=True)

cnnhistory=model.fit(x_traincnn, y_train_1, batch_size=32, epochs=200, validation_data=(x_testcnn, y_test_1),callbacks=[checkpoint])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/200
# 26/36 [====================>.........] - ETA: 0s - loss: 3.5227 - accuracy: 0.0769
# Epoch 00001: val_accuracy improved from -inf to 0.11458, saving model to best_initial_model.hdf5
# 36/36 [==============================] - 0s
val_accuracy did not improve from 0.60069
# 36/36 [==============================] - 0s 4ms/step - loss: 1.0360 - accuracy: 0.7040 - val_loss: 1.3001 - val_accuracy: 0.5833
# Epoch 101/200
# 32/36 [=========================>....] - ETA: 0s - loss: 1.0828 - accuracy: 0.6826
# Epoch 00101: val_accuracy did not improve from 0.60069
# 36/36 [==============================] - 0s 4ms/step - loss: 1.0834 - accuracy: 0.6797 - val_loss: 1.3803 - val_accuracy: 0.5486
# Epoch 102/200
# 29/36 [=======================>......] - ETA: 0s - loss: 1.0300 - accuracy: 0.7188
# Epoch 00102: val_accuracy did not improve from 0.60069
# 36/36 [==============================] - 0s 4ms/step - loss: 1.0376 - accuracy: 0.7092 - val_loss: 1.3302 - val_accuracy: 0.5660
# Epoch 103/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.9883 - accuracy: 0.7244
# Epoch 00103: val_accuracy did not improve from 0.60069
# 36/36 [==============================] - 0s 4ms/step - loss: 0.9814 - accuracy: 0.7266 - val_loss: 1.2943 - val_accuracy: 0.5799
# Epoch 104/200
# 33/36 [==========================>...] - ETA: 0s - loss: 1.0021 - accuracy: 0.7036
# Epoch 00104: val_accuracy did not improve from 0.60069
# 36/36 [==============================] - 0s 4ms/step - loss: 0.9923 - accuracy: 0.7066 - val_loss: 1.3786 - val_accuracy: 0.5556
# Epoch 105/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.9805 - accuracy: 0.7246
# Epoch 00105: val_accuracy did not improve from 0.60069
# 36/36 [==============================] - 0s 4ms/step - loss: 0.9718 - accuracy: 0.7240 - val_loss: 1.3267 - val_accuracy: 0.5799
# Epoch 106/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.9205 - accuracy: 0.7405
# Epoch 00106: val_accuracy did not improve from 0.60069
# 36/36 [==============================] - 0s 4ms/step - loss: 0.9356 - accuracy: 0.7344 - val_loss: 1.3137 - val_accuracy: 0.5660
# Epoch 107/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.9500 - accuracy: 0.7217
# Epoch 00107: val_accuracy did not improve from 0.60069
# 36/36 [==============================] - 0s 4ms/step - loss: 0.9600 - accuracy: 0.7214 - val_loss: 1.3141 - val_accuracy: 0.5694
# Epoch 108/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.9055 - accuracy: 0.7367
# Epoch 00108: val_accuracy improved from 0.60069 to 0.61458, saving model to best_initial_model.hdf5
# 36/36 [==============================] - 0s 4ms/step - loss: 0.9003 - accuracy: 0.7448 - val_loss: 1.3426 - val_accuracy: 0.6146
# Epoch 109/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.9484 - accuracy: 0.7419
# Epoch 00109: val_accuracy improved from 0.61458 to 0.62500, saving model to best_initial_model.hdf5
# 36/36 [==============================] - 0s 4ms/step - loss: 0.9533 - accuracy: 0.7439 - val_loss: 1.2818 - val_accuracy: 0.6250
# Epoch 110/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.9680 - accuracy: 0.7159
# Epoch 00110: val_accuracy did not improve from 0.62500
# 36/36 [==============================] - 0s 4ms/step - loss: 0.9571 - accuracy: 0.7231 - val_loss: 1.3207 - val_accuracy: 0.5764
# Epoch 111/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.9526 - accuracy: 0.7585
# Epoch 00111: val_accuracy did not improve from 0.62500
# 36/36 [==============================] - 0s 4ms/step - loss: 0.9652 - accuracy: 0.7526 - val_loss: 1.3275 - val_accuracy: 0.5868
# Epoch 112/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.9091 - accuracy: 0.7641
# Epoch 00112: val_accuracy did not improve from 0.62500
# 36/36 [==============================] - 0s 8ms/step - loss: 0.9179 - accuracy: 0.7595 - val_loss: 1.3290 - val_accuracy: 0.5938
# Epoch 113/200
# 30/36 [========================>.....] - ETA: 0s - loss: 0.8897 - accuracy: 0.7635
# Epoch 00113: val_accuracy did not improve from 0.62500
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8696 - accuracy: 0.7760 - val_loss: 1.3218 - val_accuracy: 0.5764
# Epoch 114/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.9353 - accuracy: 0.7399
# Epoch 00114: val_accuracy did not improve from 0.62500
# 36/36 [==============================] - 0s 4ms/step - loss: 0.9318 - accuracy: 0.7448 - val_loss: 1.4183 - val_accuracy: 0.5868
# Epoch 115/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.9537 - accuracy: 0.7359
# Epoch 00115: val_accuracy did not improve from 0.62500
# 36/36 [==============================] - 0s 4ms/step - loss: 0.9541 - accuracy: 0.7318 - val_loss: 1.2990 - val_accuracy: 0.6111
# Epoch 116/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.9391 - accuracy: 0.7238
# Epoch 00116: val_accuracy did not improve from 0.62500
# 36/36 [==============================] - 0s 4ms/step - loss: 0.9543 - accuracy: 0.7188 - val_loss: 1.3400 - val_accuracy: 0.5868
# Epoch 117/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.8615 - accuracy: 0.7666
# Epoch 00117: val_accuracy did not improve from 0.62500
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8546 - accuracy: 0.7726 - val_loss: 1.3859 - val_accuracy: 0.5625
# Epoch 118/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.9332 - accuracy: 0.7319
# Epoch 00118: val_accuracy did not improve from 0.62500
# 36/36 [==============================] - 0s 4ms/step - loss: 0.9398 - accuracy: 0.7283 - val_loss: 1.3136 - val_accuracy: 0.6146
# Epoch 119/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.8368 - accuracy: 0.7792
# Epoch 00119: val_accuracy did not improve from 0.62500
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8478 - accuracy: 0.7726 - val_loss: 1.3138 - val_accuracy: 0.6111
# Epoch 120/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.8632 - accuracy: 0.7652
# Epoch 00120: val_accuracy did not improve from 0.62500
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8455 - accuracy: 0.7708 - val_loss: 1.3121 - val_accuracy: 0.6215
# Epoch 121/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.8657 - accuracy: 0.7686
# Epoch 00121: val_accuracy did not improve from 0.62500
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8532 - accuracy: 0.7743 - val_loss: 1.3505 - val_accuracy: 0.6007
# Epoch 122/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.8657 - accuracy: 0.7756
# Epoch 00122: val_accuracy improved from 0.62500 to 0.63889, saving model to best_initial_model.hdf5
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8712 - accuracy: 0.7743 - val_loss: 1.3141 - val_accuracy: 0.6389
# Epoch 123/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.8176 - accuracy: 0.7871
# Epoch 00123: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8206 - accuracy: 0.7830 - val_loss: 1.3621 - val_accuracy: 0.6042
# Epoch 124/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.8081 - accuracy: 0.7898
# Epoch 00124: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8121 - accuracy: 0.7882 - val_loss: 1.3307 - val_accuracy: 0.6076
# Epoch 125/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.8504 - accuracy: 0.7621
# Epoch 00125: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8509 - accuracy: 0.7613 - val_loss: 1.4926 - val_accuracy: 0.5451
# Epoch 126/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.8556 - accuracy: 0.7783
# Epoch 00126: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8647 - accuracy: 0.7726 - val_loss: 1.3768 - val_accuracy: 0.5868
# Epoch 127/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.8800 - accuracy: 0.7661
# Epoch 00127: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8783 - accuracy: 0.7656 - val_loss: 1.3501 - val_accuracy: 0.6007
# Epoch 128/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.9451 - accuracy: 0.7453
# Epoch 00128: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.9449 - accuracy: 0.7431 - val_loss: 1.4325 - val_accuracy: 0.5764
# Epoch 129/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.8570 - accuracy: 0.7705
# Epoch 00129: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8589 - accuracy: 0.7700 - val_loss: 1.3015 - val_accuracy: 0.6181
# Epoch 130/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.8754 - accuracy: 0.7793
# Epoch 00130: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8883 - accuracy: 0.7734 - val_loss: 1.2838 - val_accuracy: 0.6354
# Epoch 131/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.8780 - accuracy: 0.7708
# Epoch 00131: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8742 - accuracy: 0.7752 - val_loss: 1.2775 - val_accuracy: 0.6181
# Epoch 132/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.8690 - accuracy: 0.7756
# Epoch 00132: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8623 - accuracy: 0.7769 - val_loss: 1.3071 - val_accuracy: 0.6285
# Epoch 133/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.7963 - accuracy: 0.8011
# Epoch 00133: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7953 - accuracy: 0.8021 - val_loss: 1.3198 - val_accuracy: 0.5972
# Epoch 134/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.7762 - accuracy: 0.8014
# Epoch 00134: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7954 - accuracy: 0.7934 - val_loss: 1.3907 - val_accuracy: 0.5799
# Epoch 135/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.8100 - accuracy: 0.7873
# Epoch 00135: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8096 - accuracy: 0.7943 - val_loss: 1.3422 - val_accuracy: 0.6250
# Epoch 136/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.8254 - accuracy: 0.7831
# Epoch 00136: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8155 - accuracy: 0.7865 - val_loss: 1.3681 - val_accuracy: 0.5938
# Epoch 137/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.8577 - accuracy: 0.7964
# Epoch 00137: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8530 - accuracy: 0.7995 - val_loss: 1.3348 - val_accuracy: 0.6146
# Epoch 138/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.8257 - accuracy: 0.7841
# Epoch 00138: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8271 - accuracy: 0.7847 - val_loss: 1.3239 - val_accuracy: 0.6076
# Epoch 139/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.8151 - accuracy: 0.7842
# Epoch 00139: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8360 - accuracy: 0.7795 - val_loss: 1.4003 - val_accuracy: 0.5903
# Epoch 140/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.7772 - accuracy: 0.8203
# Epoch 00140: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7909 - accuracy: 0.8160 - val_loss: 1.3407 - val_accuracy: 0.5938
# Epoch 141/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.7153 - accuracy: 0.8220
# Epoch 00141: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7326 - accuracy: 0.8203 - val_loss: 1.3992 - val_accuracy: 0.6076
# Epoch 142/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.8372 - accuracy: 0.7883
# Epoch 00142: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8334 - accuracy: 0.7891 - val_loss: 1.3580 - val_accuracy: 0.6076
# Epoch 143/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.7590 - accuracy: 0.8125
# Epoch 00143: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7687 - accuracy: 0.8151 - val_loss: 1.3281 - val_accuracy: 0.5938
# Epoch 144/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.7954 - accuracy: 0.7954
# Epoch 00144: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7978 - accuracy: 0.7908 - val_loss: 1.3233 - val_accuracy: 0.6354
# Epoch 145/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.7275 - accuracy: 0.8185
# Epoch 00145: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7415 - accuracy: 0.8142 - val_loss: 1.2807 - val_accuracy: 0.6319
# Epoch 146/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.7419 - accuracy: 0.8291
# Epoch 00146: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7366 - accuracy: 0.8307 - val_loss: 1.4326 - val_accuracy: 0.6111
# Epoch 147/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.7393 - accuracy: 0.8301
# Epoch 00147: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7456 - accuracy: 0.8238 - val_loss: 1.3209 - val_accuracy: 0.6354
# Epoch 148/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.7917 - accuracy: 0.8125
# Epoch 00148: val_accuracy did not improve from 0.63889
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7972 - accuracy: 0.8073 - val_loss: 1.4083 - val_accuracy: 0.6250
# Epoch 149/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.7773 - accuracy: 0.8223
# Epoch 00149: val_accuracy improved from 0.63889 to 0.65278, saving model to best_initial_model.hdf5
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7741 - accuracy: 0.8194 - val_loss: 1.3507 - val_accuracy: 0.6528
# Epoch 150/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.7487 - accuracy: 0.8220
# Epoch 00150: val_accuracy improved from 0.65278 to 0.65625, saving model to best_initial_model.hdf5
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7545 - accuracy: 0.8168 - val_loss: 1.3152 - val_accuracy: 0.6562
# Epoch 151/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.8091 - accuracy: 0.8078
# Epoch 00151: val_accuracy did not improve from 0.65625
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8126 - accuracy: 0.8021 - val_loss: 1.2901 - val_accuracy: 0.6354
# Epoch 152/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.8171 - accuracy: 0.7879
# Epoch 00152: val_accuracy did not improve from 0.65625
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8161 - accuracy: 0.7882 - val_loss: 1.3008 - val_accuracy: 0.6389
# Epoch 153/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.7558 - accuracy: 0.8154
# Epoch 00153: val_accuracy did not improve from 0.65625
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7520 - accuracy: 0.8151 - val_loss: 1.2353 - val_accuracy: 0.6493
# Epoch 154/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.7021 - accuracy: 0.8281
# Epoch 00154: val_accuracy did not improve from 0.65625
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7104 - accuracy: 0.8273 - val_loss: 1.2639 - val_accuracy: 0.6181
# Epoch 155/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6632 - accuracy: 0.8448
# Epoch 00155: val_accuracy improved from 0.65625 to 0.66667, saving model to best_initial_model.hdf5
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6596 - accuracy: 0.8481 - val_loss: 1.2852 - val_accuracy: 0.6667
# Epoch 156/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.7442 - accuracy: 0.8164
# Epoch 00156: val_accuracy did not improve from 0.66667
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7562 - accuracy: 0.8134 - val_loss: 1.3942 - val_accuracy: 0.6285
# Epoch 157/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.
val_accuracy did not improve from 0.66667
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6455 - accuracy: 0.8385 - val_loss: 1.3512 - val_accuracy: 0.6250
# Epoch 178/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6973 - accuracy: 0.8337
# Epoch 00178: val_accuracy did not improve from 0.66667
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6835 - accuracy: 0.8420 - val_loss: 1.3307 - val_accuracy: 0.6285
# Epoch 179/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6946 - accuracy: 0.8266
# Epoch 00179: val_accuracy did not improve from 0.66667
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7082 - accuracy: 0.8203 - val_loss: 1.3501 - val_accuracy: 0.6250
# Epoch 180/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6517 - accuracy: 0.8558
# Epoch 00180: val_accuracy did not improve from 0.66667
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6532 - accuracy: 0.8542 - val_loss: 1.3828 - val_accuracy: 0.6319
# Epoch 181/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.7648 - accuracy: 0.8301
# Epoch 00181: val_accuracy did not improve from 0.66667
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7567 - accuracy: 0.8316 - val_loss: 1.3030 - val_accuracy: 0.6319
# Epoch 182/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.7226 - accuracy: 0.8330
# Epoch 00182: val_accuracy did not improve from 0.66667
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7176 - accuracy: 0.8333 - val_loss: 1.4518 - val_accuracy: 0.6076
# Epoch 183/200
# 28/36 [======================>.......] - ETA: 0s - loss: 0.6826 - accuracy: 0.8404
# Epoch 00183: val_accuracy did not improve from 0.66667
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6762 - accuracy: 0.8438 - val_loss: 1.3174 - val_accuracy: 0.6667
# Epoch 184/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.6349 - accuracy: 0.8545
# Epoch 00184: val_accuracy did not improve from 0.66667
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6326 - accuracy: 0.8524 - val_loss: 1.4426 - val_accuracy: 0.6319
# Epoch 185/200
# 32/36 [=========================>....] - ETA: 0s - loss: 0.6419 - accuracy: 0.8652
# Epoch 00185: val_accuracy did not improve from 0.66667
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6312 - accuracy: 0.8672 - val_loss: 1.2807 - val_accuracy: 0.6458
# Epoch 186/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.6080 - accuracy: 0.8655
# Epoch 00186: val_accuracy did not improve from 0.66667
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6051 - accuracy: 0.8655 - val_loss: 1.3708 - val_accuracy: 0.6528
# Epoch 187/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.6972 - accuracy: 0.8333
# Epoch 00187: val_accuracy did not improve from 0.66667
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6791 - accuracy: 0.8420 - val_loss: 1.3126 - val_accuracy: 0.6632
# Epoch 188/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6265 - accuracy: 0.8629
# Epoch 00188: val_accuracy improved from 0.66667 to 0.67361, saving model to best_initial_model.hdf5
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6250 - accuracy: 0.8620 - val_loss: 1.3381 - val_accuracy: 0.6736
# Epoch 189/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6242 - accuracy: 0.8589
# Epoch 00189: val_accuracy did not improve from 0.67361
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6257 - accuracy: 0.8611 - val_loss: 1.3965 - val_accuracy: 0.6076
# Epoch 190/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6332 - accuracy: 0.8730
# Epoch 00190: val_accuracy did not improve from 0.67361
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6361 - accuracy: 0.8733 - val_loss: 1.2902 - val_accuracy: 0.6528
# Epoch 191/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.6936 - accuracy: 0.8532
# Epoch 00191: val_accuracy did not improve from 0.67361
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6939 - accuracy: 0.8524 - val_loss: 1.5296 - val_accuracy: 0.6354
# Epoch 192/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.7259 - accuracy: 0.8317
# Epoch 00192: val_accuracy did not improve from 0.67361
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7128 - accuracy: 0.8403 - val_loss: 1.2732 - val_accuracy: 0.6458
# Epoch 193/200
# 33/36 [==========================>...] - ETA: 0s - loss: 0.6503 - accuracy: 0.8570
# Epoch 00193: val_accuracy did not improve from 0.67361
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6583 - accuracy: 0.8559 - val_loss: 1.2824 - val_accuracy: 0.6528
# Epoch 194/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.7671 - accuracy: 0.8196
# Epoch 00194: val_accuracy did not improve from 0.67361
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7609 - accuracy: 0.8247 - val_loss: 1.3169 - val_accuracy: 0.6354
# Epoch 195/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6967 - accuracy: 0.8548
# Epoch 00195: val_accuracy did not improve from 0.67361
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6840 - accuracy: 0.8568 - val_loss: 1.3739 - val_accuracy: 0.6319
# Epoch 196/200
# 26/36 [====================>.........] - ETA: 0s - loss: 0.6754 - accuracy: 0.8462
# Epoch 00196: val_accuracy did not improve from 0.67361
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6740 - accuracy: 0.8464 - val_loss: 1.2885 - val_accuracy: 0.6354
# Epoch 197/200
# 26/36 [====================>.........] - ETA: 0s - loss: 0.6052 - accuracy: 0.8510
# Epoch 00197: val_accuracy did not improve from 0.67361
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6194 - accuracy: 0.8516 - val_loss: 1.3492 - val_accuracy: 0.6562
# Epoch 198/200
# 27/36 [=====================>........] - ETA: 0s - loss: 0.6215 - accuracy: 0.8600
# Epoch 00198: val_accuracy did not improve from 0.67361
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6264 - accuracy: 0.8602 - val_loss: 1.2890 - val_accuracy: 0.6736
# Epoch 199/200
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6581 - accuracy: 0.8589
# Epoch 00199: val_accuracy improved from 0.67361 to 0.68056, saving model to best_initial_model.hdf5
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6621 - accuracy: 0.8568 - val_loss: 1.2440 - val_accuracy: 0.6806
# Epoch 200/200
# 27/36 [=====================>........] - ETA: 0s - loss: 0.6229 - accuracy: 0.8634
# Epoch 00200: val_accuracy did not improve from 0.68056
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6357 - accuracy: 0.8611 - val_loss: 1.2986 - val_accuracy: 0.6632

# %%
# PLOT MODEL HISTORY OF ACCURACY AND LOSS OVER EPOCHS
plt.plot(cnnhistory.history['accuracy'])
plt.plot(cnnhistory.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('Initial_Model_Accuracy.png')
plt.show()
# summarize history for loss
plt.plot(cnnhistory.history['loss'])
plt.plot(cnnhistory.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('Initial_Model_loss.png')
plt.show()

# %%
predictions = model.predict_classes(x_testcnn)
# Out:
# WARNING:tensorflow:From <ipython-input-16-601d08084939>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
loss, acc = model.evaluate(x_testcnn, y_test_1)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 1.2986 - accuracy: 0.6632
# Restored model, accuracy: 66.32%

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14, model='clf', save=True):
    """Prints a confusion matrix, as returned by sklearn.metrics.confusion_matrix, as a seaborn heatmap. 
    Saves confusion matrix file to jpg file."""
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig, ax = plt.subplots(1, 1, figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, ax=ax, fmt="d", cmap=plt.cm.Oranges)
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
        
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    # fix for mpl bug that cuts off top/bottom of seaborn viz
    b, t = plt.ylim() 
    b += 0.5 
    t -= 0.5 
    plt.ylim(b, t) 
    if save == True:
        plt.savefig('tuned_' + model + '_confusion_matrix.jpg')
    plt.show()

# %%
from sklearn.metrics import classification_report 
from sklearn.metrics import confusion_matrix 
predictions = model.predict_classes(x_testcnn)
print(classification_report(y_test,predictions,target_names = targets))
print(confusion_matrix(y_test,predictions))
# Out:
#                   precision    recall  f1-score   support
#
#     angry_female       0.67      0.62      0.65        16
#       angry_male       0.90      0.78      0.84        23
#      calm_female       0.57      0.75      0.65        16
#        calm_male       0.82      0.70      0.76        20
#   disgust_female       1.00      0.35      0.52        17
#     disgust_male       0.65      0.81      0.72        16
#   fearful_female       0.83      0.90      0.86        21
#     fearful_male       0.67      0.75      0.71        16
#     happy_female       0.73      0.76      0.75        25
#       happy_male       0.75      0.54      0.63        28
#   neutral_female       0.55      0.40      0.46        15
#     neutral_male       0.55      0.75      0.63         8
#       sad_female       0.47      0.53      0.50        17
#         sad_male       0.67      0.63      0.65        19
# surprised_female       0.44      0.53      0.48        15
#   surprised_male       0.48      0.75      0.59        16
#
#         accuracy                           0.66       288
#        macro avg       0.67      0.66      0.65       288
#     weighted avg       0.69      0.66      0.66       288

# %%
print_confusion_matrix(confusion_matrix(y_test, predictions), targets, model='CNN')
